# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import data
path = "/Users/Glebazzz/Jupiter/04.25 Instacart Basket Analysis" 
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'))
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'))
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# Create a DataFrame
df_test = pd.DataFrame()

# Create a mixed type of frame
df_test['mix'] = ['a', 'b', 1, True]

# %%
# checking for mixed type 
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix
# /var/folders/fc/s6516jc11cj94_khwgp9nvn00000gq/T/ipykernel_79443/2896165857.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)

# %%
# Correct way to do this check
for col in df_test.columns.tolist():
  weird = df_test[col].map(type) != type(df_test[col].iloc[0])
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix

# %%
df_test['mix'] = df_test['mix'].astype('str')

# %% [markdown]
# Note that this will convert a column’s data type from numeric to string, but there may be times where you need to go in the opposite direction, as well—from string to numeric. To change this, simply update the str within the astype() function to int64 or whichever numeric data type you want to use.

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_nan = df_prods[df_prods['product_name'] .isnull() == True]
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14   12.20
# 68             69          NaN        26              7   11.80
# 115           116          NaN        93              3   10.80
# 261           262          NaN       110             13   12.10
# 525           525          NaN       109             11    1.20
# 1511         1511          NaN        84             16   14.30
# 1780         1780          NaN       126             11   12.30
# 2240         2240          NaN        52              1   14.20
# 2586         2586          NaN       104             13   12.40
# 3159         3159          NaN       126             11   13.10
# 3230         3230          NaN       120             16   14.40
# 3736         3736          NaN        41              8   14.80
# 4283         4283          NaN        77              7   14.40
# 4790         4790          NaN        91             16   14.50
# ...

# %%
df_nan.describe()
# Out:
#        product_id  aisle_id  department_id  prices
# count       16.00     16.00          16.00   16.00
# mean      6684.00     89.94          10.94   13.01
# std      12836.67     33.73           4.64    3.88
# min         34.00     26.00           1.00    1.20
# 25%        459.25     70.75           7.75   12.17
# 50%       2413.00     98.50          11.50   13.65
# 75%       3872.75    120.00          14.50   14.43
# max      40440.00    126.00          16.00   20.90

# %% [markdown]
# If you choose to use the mean, you can use the df.describe() function to find the mean of the column in question, then use the following code to replace your missing values with it:
#
# df['column with missings'].fillna(mean value, inplace=True)
# If you choose to use the median, you can find it using the df_prods.median() function, then use the same command as above, only replacing “mean value” with “median value”:
#
# df['column with missings'].fillna(median value, inplace=True)

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]
df_prods_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19    5.80
# 1           104             13    9.30
# ...

# %%
#another way to clean missing data
df_prods.dropna(inplace = True)

# %%
#If you wanted to use this command to drop only the NaNs from a particular column, the code would look like this:

df_prods.dropna(subset = ['product_name'], inplace = True)

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11    4.80
# 18459        27              5    9.20
# 26810        27              5   13.40
# 35309       121             14    6.80
# 35495       127             11    9.90

# %%
# Addressing Duplicates
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_prods_clean.drop_duplicates()
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %% [markdown]
# # Exercise

# %%
#Checking for mixed types
for col in df_ords.columns.tolist():
  weird = df_ords[col].map(type) != type(df_ords[col].iloc[0])
  if len (df_ords[weird]) > 0:
    print (col)
# Out:
# Unnamed: 0
# order_id
# user_id
# order_number
# orders_day_of_week
# hour
# days_since_prior_order

# %%
df_ords.describe()
# Out:
#        Unnamed: 0   order_id    user_id  order_number  orders_day_of_week  \
# count  3421083.00 3421083.00 3421083.00    3421083.00          3421083.00
# mean   1710541.00 1710542.00  102978.21         17.15                2.78
# std     987581.74  987581.74   59533.72         17.73                2.05
# min          0.00       1.00       1.00          1.00                0.00
# 25%     855270.50  855271.50   51394.00          5.00                1.00
# 50%    1710541.00 1710542.00  102689.00         11.00                3.00
# 75%    2565811.50 2565812.50  154385.00         23.00                5.00
# max    3421082.00 3421083.00  206209.00        100.00                6.00
#
#             hour  days_since_prior_order
# count 3421083.00              3214874.00
# mean       13.45                   11.11
# std         4.23                    9.21
# min         0.00                    0.00
# 25%        10.00                    4.00
# 50%        13.00                    7.00
# ...

# %% [markdown]
# unuseful unnamed collomn should be deleted.
# 100 max orders looks strange compared to std and mean
# orders hour = 0 not typical
# days_since_prior_order = 0 looks untypical

# %% [markdown]
# ### If you find mixed-type data, fix it. The column in question should contain observations of a single data type.

# %%
#Checking for mixed types
for col in df_ords.columns.tolist():
  weird = df_ords[col].map(type) != type(df_ords[col].iloc[0])
  if len (df_ords[weird]) > 0:
    print (col)
# Out:
# Unnamed: 0
# order_id
# user_id
# order_number
# orders_day_of_week
# hour
# days_since_prior_order

# %% [markdown]
# there is no mixed data

# %% [markdown]
# ## Address the missing values using an appropriate method. In a markdown cell, explain why you used your method of choice.

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 1                 1   2398795        1             2                   3
# 2                 2    473747        1             3                   3
# 3                 3   2254736        1             4                   4
# 4                 4    431534        1             5                   4
# ...             ...       ...      ...           ...                 ...
# 3421078     3421078   2266710   206209            10                   5
# 3421079     3421079   1854736   206209            11                   4
# 3421080     3421080    626363   206209            12                   1
# 3421081     3421081   2977660   206209            13                   1
# 3421082     3421082    272231   206209            14                   6
#
#          hour  days_since_prior_order
# 0           8                     NaN
# ...

# %%
df_nan = df_ords[df_ords['days_since_prior_order'] .isnull() == True]
df_nan.describe()
# Out:
#        Unnamed: 0   order_id   user_id  order_number  orders_day_of_week  \
# count   206209.00  206209.00 206209.00     206209.00           206209.00
# mean   1712636.73 1708461.83 103105.00          1.00                2.75
# std     987481.64  988129.90  59527.56          0.00                2.08
# min          0.00      20.00      1.00          1.00                0.00
# 25%     857973.00  850730.00  51553.00          1.00                1.00
# 50%    1717068.00 1706246.00 103105.00          1.00                3.00
# 75%    2570518.00 2564292.00 154657.00          1.00                5.00
# max    3421069.00 3421081.00 206209.00          1.00                6.00
#
#            hour  days_since_prior_order
# count 206209.00                    0.00
# mean      13.63                     NaN
# std        4.22                     NaN
# min        0.00                     NaN
# 25%       11.00                     NaN
# 50%       14.00                     NaN
# ...

# %%
df_ords['user_id'].value_counts(dropna = False)
# Out:
# user_id
# 152340    100
# 185641    100
# 185524    100
# 81678     100
# 70922     100
#          ...
# 13046       4
# 70208       4
# 111440      4
# 31762       4
# 47980       4
# Name: count, Length: 206209, dtype: int64

# %%
#Run a check for missing values in the df_ords dataframe.
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# orders_day_of_week             0
# hour                           0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# # 206209.00 NAN records (probably linked to the very first order of each unique user_id.)
# There is no sense to imputate these data.

# %%
#Find out the the missing values based on user_id count summarized 
df_ords[df_ords['days_since_prior_order'].isnull()].groupby('user_id').count().describe()
# Out:
#        order_id  order_number  orders_day_of_week  hour  \
# count      0.00          0.00                0.00  0.00
# mean        NaN           NaN                 NaN   NaN
# std         NaN           NaN                 NaN   NaN
# min         NaN           NaN                 NaN   NaN
# 25%         NaN           NaN                 NaN   NaN
# 50%         NaN           NaN                 NaN   NaN
# 75%         NaN           NaN                 NaN   NaN
# max         NaN           NaN                 NaN   NaN
#
#        days_since_prior_order
# count                    0.00
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %% [markdown]
# ## Run a check for duplicate values in your df_ords data.

# %%
df_ords_clean = df_ords[df_ords['order_id'].isnull() == False]
df_ords_clean
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 1                 1   2398795        1             2                   3
# 2                 2    473747        1             3                   3
# 3                 3   2254736        1             4                   4
# 4                 4    431534        1             5                   4
# ...             ...       ...      ...           ...                 ...
# 3421078     3421078   2266710   206209            10                   5
# 3421079     3421079   1854736   206209            11                   4
# 3421080     3421080    626363   206209            12                   1
# 3421081     3421081   2977660   206209            13                   1
# 3421082     3421082    272231   206209            14                   6
#
#          hour  days_since_prior_order
# 0           8                     NaN
# ...

# %%
df_dups = df_ords_clean[df_ords_clean.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_number, orders_day_of_week, hour, days_since_prior_order]
# Index: []

# %% [markdown]
# There is no duplicates

# %%
#Dropping the column "Unnamed: 0" from the df_ords dataframe and assinged it to a new dataframe "df_ords_clean"
df_ords_clean = df_ords.drop('Unnamed: 0', axis=1)

# %%
df_ords_clean
# Out:
#          order_id  user_id  order_number  orders_day_of_week  hour  \
# 0         2539329        1             1                   2     8
# 1         2398795        1             2                   3     7
# 2          473747        1             3                   3    12
# 3         2254736        1             4                   4     7
# 4          431534        1             5                   4    15
# ...           ...      ...           ...                 ...   ...
# 3421078   2266710   206209            10                   5    18
# 3421079   1854736   206209            11                   4    10
# 3421080    626363   206209            12                   1    12
# 3421081   2977660   206209            13                   1    12
# 3421082    272231   206209            14                   6    14
#
#          days_since_prior_order
# 0                           NaN
# 1                         15.00
# 2                         21.00
# ...

# %% [markdown]
# 100 orders

# %%
print(df_ords['order_number'].describe())
# Out:
# count   3421083.00
# mean         17.15
# std          17.73
# min           1.00
# 25%           5.00
# 50%          11.00
# 75%          23.00
# max         100.00
# Name: order_number, dtype: float64

# %%
df_prods.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products cleaned.csv'))

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders cleaned.csv'))
