# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import combined data
path = "/Users/Glebazzz/Jupiter/04.25 Instacart Basket Analysis" 
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
# Import Products data
path = "/Users/Glebazzz/Jupiter/04.25 Instacart Basket Analysis" 
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products cleaned.csv'))

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49688       49688       49684
# 49689       49689       49685
# 49690       49690       49686
# 49691       49691       49687
# 49692       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49688          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Drop additional colomns 
df_prods = df_prods.drop(columns=[ 'Unnamed: 0'])

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_orders_products_combined
# Out:
#           Unnamed: 0.1  order_id  user_id  order_number  orders_day_of_week  \
# 0                    0   2539329        1             1                   2
# 1                    0   2539329        1             1                   2
# 2                    0   2539329        1             1                   2
# 3                    0   2539329        1             1                   2
# 4                    0   2539329        1             1                   2
# ...                ...       ...      ...           ...                 ...
# 32434484       3421081   2977660   206209            13                   1
# 32434485       3421081   2977660   206209            13                   1
# 32434486       3421081   2977660   206209            13                   1
# 32434487       3421081   2977660   206209            13                   1
# 32434488       3421081   2977660   206209            13                   1
#
# ...

# %%
# Drop old merge colomn 
if '_merge' in df_orders_products_combined.columns:
    df_orders_products_combined = df_orders_products_combined.drop(columns=['_merge'])

# %%
# merging
df_op_combined = df_prods.merge(df_orders_products_combined, on = 'product_id', indicator = True, how = 'inner')

# %%
#checking merge
df_op_combined['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# merging
df_op_combined = df_prods.merge(df_orders_products_combined, on = 'product_id', indicator = True, how = 'inner')

# %%
#checking merge
df_op_combined['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# exporting
df_op_combined.to_csv(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.csv'))

# %%
# exporting
df_op_combined.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
